# %%
# Inspired by the Basset tutorials: https://github.com/davek44/Basset/blob/master/tutorials/prepare_compendium.ipynb

# %%
# Call shell script to wget all files

# %%
# !python3 preprocess_atacseq.py -directory '../0_data/1_exp_data/bed/raw' -maxoverlap 200 -sequencelength 600
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# FILE: 1
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# All 600 bp for this file!
# ...

# %% [markdown]
# some stuff to check: chr1	249219020	249219170	.	43.000000
# check this as well, not 600 bp: 20801140 20801290
