# %%
# Inspired by the Basset tutorials: https://github.com/davek44/Basset/blob/master/tutorials/prepare_compendium.ipynb

# %%
# Call shell script to wget all files

# %%
# !python3 preprocess_atacseq.py -directory '../0_data/1_exp_data/bed/test' -maxoverlap 200 -sequencelength 600
# Out:
# These are the cell types:  dict_keys(['E004.bed', 'E003.bed'])
# This is the number of active intervals 201393
